# %% [raw]
# Mobility: Google COVID-19 Community Mobility Reports
# ###########################################################################
# This section describes how to use the Google mobility reports client
# from Episuite. The main class used to download and parse the Google
# mobility data is the :class:`~episuite.mobility.google.GoogleMobility`.
#
# .. seealso::
#
#    `Google COVID-19 Community Mobility Reports  <https://www.google.com/covid19/mobility//>`_
#       Google COVID-19 Community Mobility Reports.
#
#    Module :mod:`episuite.mobility.google`
#       Documentation of the :py:mod:`episuite.mobility.google` module.

# %%
from matplotlib import pyplot as plt
from episuite.mobility import google

# %% [markdown]
# ### Load Google mobility data
# The Episuite API for the Google mobility reports allows you to download the entire dataset or to filter by a single country by using a country/region code. We will here just download data from Brazil using the `BR` country code.
#
# The mobility reports are increasing in size every day, that's why filtering by your country code is highly recommended. If you specify the `country_region_code` while calling the `load_report()`, Episuite will filter the dataset without loading it entirely to memory.

# %%
client = google.GoogleMobility()

# %%
mobility_data = client.load_report(country_region_code="BR",
                                   show_progress=True, cache=True)

# %%
mobility_data.tail(5)
# Out:
#         country_region_code country_region        sub_region_1  \
# 1148236                  BR         Brazil  State of Tocantins
# 1148237                  BR         Brazil  State of Tocantins
# 1148238                  BR         Brazil  State of Tocantins
# 1148239                  BR         Brazil  State of Tocantins
# 1148240                  BR         Brazil  State of Tocantins
#
#            sub_region_2  metro_area iso_3166_2_code  census_fips_code  \
# 1148236  Tocantinópolis         NaN             NaN               NaN
# 1148237  Tocantinópolis         NaN             NaN               NaN
# 1148238  Tocantinópolis         NaN             NaN               NaN
# 1148239  Tocantinópolis         NaN             NaN               NaN
# 1148240  Tocantinópolis         NaN             NaN               NaN
#
#                             place_id       date  \
# 1148236  ChIJdy1nSeuG2pIR7Nmgv2Wq2uo 2021-03-11
# 1148237  ChIJdy1nSeuG2pIR7Nmgv2Wq2uo 2021-03-12
# 1148238  ChIJdy1nSeuG2pIR7Nmgv2Wq2uo 2021-03-13
# 1148239  ChIJdy1nSeuG2pIR7Nmgv2Wq2uo 2021-03-15
# 1148240  ChIJdy1nSeuG2pIR7Nmgv2Wq2uo 2021-03-16
#
#          retail_and_recreation_percent_change_from_baseline  \
# 1148236                                                NaN
# 1148237                                                NaN
# 1148238                                                NaN
# 1148239                                                NaN
# 1148240                                                NaN
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 1148236                                                NaN
# 1148237                                                NaN
# 1148238                                                NaN
# 1148239                                                NaN
# 1148240                                                NaN
#
#          parks_percent_change_from_baseline  \
# 1148236                                 NaN
# 1148237                                 NaN
# 1148238                                 NaN
# 1148239                                 NaN
# 1148240                                 NaN
#
#          transit_stations_percent_change_from_baseline  \
# 1148236                                            NaN
# 1148237                                            NaN
# 1148238                                            NaN
# 1148239                                            NaN
# 1148240                                            NaN
#
#          workplaces_percent_change_from_baseline  \
# 1148236                                     -1.0
# 1148237                                     13.0
# 1148238                                      7.0
# 1148239                                      3.0
# 1148240                                      5.0
#
#          residential_percent_change_from_baseline
# 1148236                                       NaN
# 1148237                                       NaN
# 1148238                                       NaN
# 1148239                                       NaN
# 1148240                                       NaN
